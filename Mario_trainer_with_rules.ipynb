# %%
import os 
import gym
import gym_super_mario_bros
from gym_super_mario_bros.actions import RIGHT_ONLY
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback
from nes_py.wrappers import JoypadSpace
import tensorboard as tf

# Função para criar o ambiente
def make_env():
    env = gym_super_mario_bros.make('SuperMarioBros-v1')
    env = JoypadSpace(env, RIGHT_ONLY)
    env = gym.wrappers.GrayScaleObservation(env, keep_dim=True)
    env = CustomRescaleObservation(env, low=0, high=255)
    env = gym.wrappers.FrameStack(env, num_stack=6)
    return env

# Classe personalizada para redimensionar as observações
class CustomRescaleObservation(gym.ObservationWrapper):
    def __init__(self, env, low, high):
        super(CustomRescaleObservation, self).__init__(env)
        self.low = low
        self.high = high

    def observation(self, observation):
        return observation * (self.high - self.low) + self.low

# Callback personalizado para recompensas e penalidades
class CustomCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(CustomCallback, self).__init__(verbose)
        self.x_pos = None
        self.check_freq = check_freq
        self.save_path = save_path
        self.rewards = 0
        self.time_before = None
        self.progress_bar = None

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        # Obtem informações sobre o ambiente após a etapa
        info = self.locals.get("info", {})

        # Recompensa o agente com base na diferença de x (v) entre os estados
        x_pos_after = info.get("x_pos", 0)
        self.x_pos = x_pos_after
        if self.x_pos is not None:
            v = x_pos_after - self.x_pos
            if v < 0:
                v = 1
            if v > 0:
                v = 2
            if v == 0:
                v = 0

        # Recompensa o agente com base na diferença no relógio (c) entre os estados
        time_after = info.get("time", 0)
        self.time_before = time_after
        if self.time_before is not None:
            c = self.time_before - time_after
            if c >= 0:
                c = 0
            else:
                c = -1

        # Recompensas adicionais por coletar moedas e derrotar inimigos
        coins_collected = info.get("coins", 0)
        enemies_defeated = info.get("enemies_defeated", 0)
        additional_reward = coins_collected * 20 + enemies_defeated * 50

        # Recompensas adicionais com base na eficiência do agente (mais rápido e menos etapas)
        remaining_time = info.get("remaining_time", 0)
        num_steps = info.get("num_steps", 0)
        time_reward = remaining_time * 2
        steps_reward = -num_steps * 2

        # Penaliza o agente por morrer (d)
        d = -15 if "life" in info and info["life"] < 1 else 0

        if info.get("flag_get", False):
            reward = 15
            return True

        # Soma as recompensas e penalidades para calcular a recompensa total
        reward = v + c + d + additional_reward + time_reward + steps_reward

        # Salva a recompensa total no log
        self.rewards += reward
        self.logger.record("reward", self.rewards)

        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'melhor_modelo_mario_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True


# Cria o ambiente do jogo
env = make_env()

# Diretórios onde seram salvos os modelos e logs
CHECKPOINT_DIR = './mario_model_v4/'
LOG_DIR = './logs_v2/'

# Crie o modelo PPO com a política MlpPolicy ou Use um já salvo
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=LOG_DIR, batch_size=128, learning_rate=0.0005, vf_coef=0.5, ent_coef=0.01, n_steps=512)
## model = PPO.load('./mario_model_v3/melhor_modelo_mario_450000', env=env, tensorboard_log=LOG_DIR, batch_size=128, learning_rate=0.0005, vf_coef=0.5, ent_coef=0.01) ##2

# Declaração do treinamento com callback personalizado
custom_callback = CustomCallback(check_freq=50000, save_path=CHECKPOINT_DIR)
model.learn(total_timesteps=1000000, callback=custom_callback)

# Salva o modelo depois de concluir
model.save("mario_model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs_v2/PPO_5
# ----------------------------
# | reward             | 0   |
# | time/              |     |
# |    fps             | 117 |
# |    iterations      | 1   |
# |    time_elapsed    | 4   |
# |    total_timesteps | 512 |
# ----------------------------
# ------------------------------------------
# | reward                  | 0            |
# | time/                   |              |
# |    fps                  | 50           |
# |    iterations           | 2            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0017979961 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.61        |
# |    explained_variance   | -0.0102      |
# |    learning_rate        | 0.0005       |
# |    loss                 | 191          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -1.54e-05    |
# |    value_loss           | 473          |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 40          |
# |    iterations           | 3           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 1536        |
# | train/                  |             |
# |    approx_kl            | 0.014978015 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.267       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00998    |
# |    value_loss           | 2.59        |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 4            |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0108232405 |
# |    clip_fraction        | 0.0855       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0253       |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00907     |
# |    value_loss           | 0.697        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 5           |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.009492215 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0392      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00545    |
# |    value_loss           | 0.607       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 6           |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.015697166 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00109    |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00433    |
# |    value_loss           | 0.35        |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 7           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 3584        |
# | train/                  |             |
# |    approx_kl            | 0.011411041 |
# |    clip_fraction        | 0.0986      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0177      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 0.259       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 8            |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0069676773 |
# |    clip_fraction        | 0.00527      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | 4.75e-05     |
# |    learning_rate        | 0.0005       |
# |    loss                 | 50.5         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00708     |
# |    value_loss           | 110          |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 9           |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 4608        |
# | train/                  |             |
# |    approx_kl            | 0.008525575 |
# |    clip_fraction        | 0.00586     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0998      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00193    |
# |    value_loss           | 1.03        |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 10          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.007095748 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0323      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.000277   |
# |    value_loss           | 0.378       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 11           |
# |    time_elapsed         | 169          |
# |    total_timesteps      | 5632         |
# | train/                  |              |
# |    approx_kl            | 0.0071915393 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0263       |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0035      |
# |    value_loss           | 0.394        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 12          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.006754078 |
# |    clip_fraction        | 0.024       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0334      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 0.251       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 13          |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.010881169 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00593     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 0.174       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 14           |
# |    time_elapsed         | 216          |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0130414525 |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.6         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0255       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0186      |
# |    value_loss           | 0.131        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 15          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.011538008 |
# |    clip_fraction        | 0.0475      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0005      |
# |    loss                 | -0.00264    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00444    |
# |    value_loss           | 0.125       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 16          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015340825 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.00418     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00858    |
# |    value_loss           | 0.11        |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 17           |
# |    time_elapsed         | 263          |
# |    total_timesteps      | 8704         |
# | train/                  |              |
# |    approx_kl            | 0.0026819964 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.56        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0005       |
# |    loss                 | 160          |
# |    n_updates            | 160          |
# |    policy_gradient_loss | 0.00266      |
# |    value_loss           | 385          |
# ------------------------------------------
# -------------------------------------------
# | reward                  | 0             |
# | time/                   |               |
# |    fps                  | 33            |
# |    iterations           | 18            |
# |    time_elapsed         | 278           |
# |    total_timesteps      | 9216          |
# | train/                  |               |
# |    approx_kl            | 4.5207795e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.55         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0005        |
# |    loss                 | 71.1          |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -0.000168     |
# |    value_loss           | 167           |
# -------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 19          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.005088726 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.124       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0018     |
# |    value_loss           | 0.723       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 20          |
# |    time_elapsed         | 310         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.018280119 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.087       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00823    |
# |    value_loss           | 0.431       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 21           |
# |    time_elapsed         | 325          |
# |    total_timesteps      | 10752        |
# | train/                  |              |
# |    approx_kl            | 0.0018446712 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.45        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 45.1         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.000568    |
# |    value_loss           | 84.5         |
# ------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 22           |
# |    time_elapsed         | 341          |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0063828444 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.46        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0656       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 0.665        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 23          |
# |    time_elapsed         | 357         |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.019420989 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0659      |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 0.329       |
# -----------------------------------------
# ----------------------------------------
# | reward                  | 0          |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 24         |
# |    time_elapsed         | 374        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00752567 |
# |    clip_fraction        | 0.0834     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.51      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0905     |
# |    n_updates            | 230        |
# |    policy_gradient_loss | -0.00789   |
# |    value_loss           | 0.35       |
# ----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 25          |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.012085227 |
# |    clip_fraction        | 0.0186      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0813      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0018     |
# |    value_loss           | 0.299       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 26           |
# |    time_elapsed         | 405          |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0057497304 |
# |    clip_fraction        | 0.0109       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0896       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 0.26         |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 27          |
# |    time_elapsed         | 422         |
# |    total_timesteps      | 13824       |
# | train/                  |             |
# |    approx_kl            | 0.011897037 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0581      |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0032     |
# |    value_loss           | 0.23        |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 28          |
# |    time_elapsed         | 438         |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011462135 |
# |    clip_fraction        | 0.0852      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0197      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00825    |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 29          |
# |    time_elapsed         | 454         |
# |    total_timesteps      | 14848       |
# | train/                  |             |
# |    approx_kl            | 0.015575786 |
# |    clip_fraction        | 0.0545      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0209      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 0.0967      |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 30          |
# |    time_elapsed         | 470         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.013467274 |
# |    clip_fraction        | 0.0768      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0156      |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00658    |
# |    value_loss           | 0.0938      |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 31          |
# |    time_elapsed         | 485         |
# |    total_timesteps      | 15872       |
# | train/                  |             |
# |    approx_kl            | 0.012905642 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0128      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00785    |
# |    value_loss           | 0.0934      |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 32          |
# |    time_elapsed         | 502         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.012895336 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0114      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00393    |
# |    value_loss           | 0.089       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 759          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 33           |
# |    time_elapsed         | 519          |
# |    total_timesteps      | 16896        |
# | train/                  |              |
# |    approx_kl            | 0.0023736272 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 378          |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00367     |
# |    value_loss           | 750          |
# ------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 759          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 34           |
# |    time_elapsed         | 535          |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0002867676 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0005       |
# |    loss                 | 61.7         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000645    |
# |    value_loss           | 108          |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 35          |
# |    time_elapsed         | 552         |
# |    total_timesteps      | 17920       |
# | train/                  |             |
# |    approx_kl            | 0.006972242 |
# |    clip_fraction        | 0.0205      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.03        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00272    |
# |    value_loss           | 0.304       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 36          |
# |    time_elapsed         | 568         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.006066002 |
# |    clip_fraction        | 0.0242      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0288      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00384    |
# |    value_loss           | 0.15        |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 759          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 37           |
# |    time_elapsed         | 584          |
# |    total_timesteps      | 18944        |
# | train/                  |              |
# |    approx_kl            | 0.0047737085 |
# |    clip_fraction        | 0.0084       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0261       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.000626    |
# |    value_loss           | 0.143        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 38          |
# |    time_elapsed         | 600         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.000987591 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 98.2        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00107    |
# |    value_loss           | 219         |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 759          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 39           |
# |    time_elapsed         | 616          |
# |    total_timesteps      | 19968        |
# | train/                  |              |
# |    approx_kl            | 2.126093e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.41        |
# |    explained_variance   | 1.67e-05     |
# |    learning_rate        | 0.0005       |
# |    loss                 | 152          |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -1.7e-05     |
# |    value_loss           | 290          |
# ------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 759          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 40           |
# |    time_elapsed         | 634          |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0026597544 |
# |    clip_fraction        | 0.00117      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0294       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 0.476        |
# ------------------------------------------
# ----------------------------------------
# | reward                  | 0          |
# | rollout/                |            |
# |    ep_len_mean          | 1.62e+04   |
# |    ep_rew_mean          | 759        |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 41         |
# |    time_elapsed         | 650        |
# |    total_timesteps      | 20992      |
# | train/                  |            |
# |    approx_kl            | 0.00913009 |
# |    clip_fraction        | 0.0594     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.44      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0246     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00247   |
# |    value_loss           | 0.18       |
# ----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 42          |
# |    time_elapsed         | 666         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.009006866 |
# |    clip_fraction        | 0.00313     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.047       |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.000811   |
# |    value_loss           | 0.201       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 43          |
# |    time_elapsed         | 682         |
# |    total_timesteps      | 22016       |
# | train/                  |             |
# |    approx_kl            | 0.011841767 |
# |    clip_fraction        | 0.0178      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0362      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.000853   |
# |    value_loss           | 0.16        |
# -----------------------------------------
# ----------------------------------------
# | reward                  | 0          |
# | rollout/                |            |
# |    ep_len_mean          | 1.62e+04   |
# |    ep_rew_mean          | 759        |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 44         |
# |    time_elapsed         | 697        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.01173329 |
# |    clip_fraction        | 0.0178     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.45      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0338     |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.00246   |
# |    value_loss           | 0.144      |
# ----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 45          |
# |    time_elapsed         | 713         |
# |    total_timesteps      | 23040       |
# | train/                  |             |
# |    approx_kl            | 0.013890783 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0133      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 0.116       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 46          |
# |    time_elapsed         | 728         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.008606914 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0169      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.106       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 759          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 47           |
# |    time_elapsed         | 744          |
# |    total_timesteps      | 24064        |
# | train/                  |              |
# |    approx_kl            | 0.0004477821 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 50.2         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.000817    |
# |    value_loss           | 86.3         |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 48          |
# |    time_elapsed         | 762         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.010177385 |
# |    clip_fraction        | 0.0285      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0334      |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.004      |
# |    value_loss           | 0.195       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 759          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 49           |
# |    time_elapsed         | 779          |
# |    total_timesteps      | 25088        |
# | train/                  |              |
# |    approx_kl            | 0.0065066535 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0172       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00395     |
# |    value_loss           | 0.12         |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 50          |
# |    time_elapsed         | 795         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.006035026 |
# |    clip_fraction        | 0.0566      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.061       |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0035     |
# |    value_loss           | 0.205       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 51          |
# |    time_elapsed         | 811         |
# |    total_timesteps      | 26112       |
# | train/                  |             |
# |    approx_kl            | 0.013524368 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0964      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0084     |
# |    value_loss           | 0.247       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 52          |
# |    time_elapsed         | 826         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.013985304 |
# |    clip_fraction        | 0.0807      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.45       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0602      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00737    |
# |    value_loss           | 0.231       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 53          |
# |    time_elapsed         | 842         |
# |    total_timesteps      | 27136       |
# | train/                  |             |
# |    approx_kl            | 0.005209674 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0541      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0086     |
# |    value_loss           | 0.213       |
# -----------------------------------------
# -------------------------------------------
# | reward                  | 0             |
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 759           |
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 54            |
# |    time_elapsed         | 857           |
# |    total_timesteps      | 27648         |
# | train/                  |               |
# |    approx_kl            | 0.00061564497 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.48         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0005        |
# |    loss                 | 200           |
# |    n_updates            | 530           |
# |    policy_gradient_loss | -0.000749     |
# |    value_loss           | 362           |
# -------------------------------------------
# -------------------------------------------
# | reward                  | 0             |
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 759           |
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 55            |
# |    time_elapsed         | 873           |
# |    total_timesteps      | 28160         |
# | train/                  |               |
# |    approx_kl            | 4.8826914e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.47         |
# |    explained_variance   | 1.46e-05      |
# |    learning_rate        | 0.0005        |
# |    loss                 | 121           |
# |    n_updates            | 540           |
# |    policy_gradient_loss | -7.51e-05     |
# |    value_loss           | 242           |
# -------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 759         |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 56          |
# |    time_elapsed         | 888         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.013319109 |
# |    clip_fraction        | 0.0303      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0704      |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00639    |
# |    value_loss           | 0.41        |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 759          |
# ...
# |    value_loss           | 0.444       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.66e+04     |
# |    ep_rew_mean          | 795          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 299          |
# |    time_elapsed         | 4955         |
# |    total_timesteps      | 153088       |
# | train/                  |              |
# |    approx_kl            | 0.0061461357 |
# |    clip_fraction        | 0.00918      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0343       |
# |    n_updates            | 2980         |
# |    policy_gradient_loss | -0.00122     |
# |    value_loss           | 0.174        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.66e+04    |
# |    ep_rew_mean          | 795         |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 300         |
# |    time_elapsed         | 4979        |
# |    total_timesteps      | 153600      |
# | train/                  |             |
# |    approx_kl            | 0.007180735 |
# |    clip_fraction        | 0.0246      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0232      |
# |    n_updates            | 2990        |
# |    policy_gradient_loss | -0.00176    |
# |    value_loss           | 0.184       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.66e+04    |
# |    ep_rew_mean          | 795         |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 301         |
# |    time_elapsed         | 5004        |
# |    total_timesteps      | 154112      |
# | train/                  |             |
# |    approx_kl            | 0.005433752 |
# |    clip_fraction        | 0.0439      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.994      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0263      |
# |    n_updates            | 3000        |
# |    policy_gradient_loss | -0.00398    |
# |    value_loss           | 0.154       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.66e+04     |
# |    ep_rew_mean          | 795          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 302          |
# |    time_elapsed         | 5027         |
# |    total_timesteps      | 154624       |
# | train/                  |              |
# |    approx_kl            | 0.0016472113 |
# |    clip_fraction        | 0.00937      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.973       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0406       |
# |    n_updates            | 3010         |
# |    policy_gradient_loss | -0.00139     |
# |    value_loss           | 0.129        |
# ------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.66e+04     |
# |    ep_rew_mean          | 795          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 303          |
# |    time_elapsed         | 5054         |
# |    total_timesteps      | 155136       |
# | train/                  |              |
# |    approx_kl            | 0.0059404387 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.896       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0198       |
# |    n_updates            | 3020         |
# |    policy_gradient_loss | -0.00466     |
# |    value_loss           | 0.108        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.66e+04    |
# |    ep_rew_mean          | 795         |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 304         |
# |    time_elapsed         | 5073        |
# |    total_timesteps      | 155648      |
# | train/                  |             |
# |    approx_kl            | 0.010494762 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.958      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0265      |
# |    n_updates            | 3030        |
# |    policy_gradient_loss | -0.00524    |
# |    value_loss           | 0.1         |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.66e+04    |
# |    ep_rew_mean          | 795         |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 305         |
# |    time_elapsed         | 5088        |
# |    total_timesteps      | 156160      |
# | train/                  |             |
# |    approx_kl            | 0.005273219 |
# |    clip_fraction        | 0.0324      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0219      |
# |    n_updates            | 3040        |
# |    policy_gradient_loss | -0.00172    |
# |    value_loss           | 0.095       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.66e+04     |
# |    ep_rew_mean          | 795          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 306          |
# |    time_elapsed         | 5104         |
# |    total_timesteps      | 156672       |
# | train/                  |              |
# |    approx_kl            | 0.0026408036 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.023        |
# |    n_updates            | 3050         |
# |    policy_gradient_loss | -0.00311     |
# |    value_loss           | 0.0927       |
# ------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.57e+04     |
# |    ep_rew_mean          | 832          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 307          |
# |    time_elapsed         | 5121         |
# |    total_timesteps      | 157184       |
# | train/                  |              |
# |    approx_kl            | 0.0068989224 |
# |    clip_fraction        | 0.0703       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0233       |
# |    n_updates            | 3060         |
# |    policy_gradient_loss | -0.00691     |
# |    value_loss           | 0.0917       |
# ------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.57e+04     |
# |    ep_rew_mean          | 832          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 308          |
# |    time_elapsed         | 5139         |
# |    total_timesteps      | 157696       |
# | train/                  |              |
# |    approx_kl            | 0.0014505262 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 250          |
# |    n_updates            | 3070         |
# |    policy_gradient_loss | -0.00328     |
# |    value_loss           | 610          |
# ------------------------------------------
# -------------------------------------------
# | reward                  | 0             |
# | rollout/                |               |
# |    ep_len_mean          | 1.57e+04      |
# |    ep_rew_mean          | 832           |
# | time/                   |               |
# |    fps                  | 30            |
# |    iterations           | 309           |
# |    time_elapsed         | 5155          |
# |    total_timesteps      | 158208        |
# | train/                  |               |
# |    approx_kl            | 2.1789107e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.06         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0005        |
# |    loss                 | 89.4          |
# |    n_updates            | 3080          |
# |    policy_gradient_loss | -0.000178     |
# |    value_loss           | 213           |
# -------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.57e+04    |
# |    ep_rew_mean          | 832         |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 310         |
# |    time_elapsed         | 5171        |
# |    total_timesteps      | 158720      |
# | train/                  |             |
# |    approx_kl            | 0.004042721 |
# |    clip_fraction        | 0.00742     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0484      |
# |    n_updates            | 3090        |
# |    policy_gradient_loss | -0.00163    |
# |    value_loss           | 0.315       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.57e+04    |
# |    ep_rew_mean          | 832         |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 311         |
# |    time_elapsed         | 5189        |
# |    total_timesteps      | 159232      |
# | train/                  |             |
# |    approx_kl            | 0.005344948 |
# |    clip_fraction        | 0.016       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.98       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0277      |
# |    n_updates            | 3100        |
# |    policy_gradient_loss | -0.00145    |
# |    value_loss           | 0.153       |
# -----------------------------------------
# ----------------------------------------
# | reward                  | 0          |
# | rollout/                |            |
# |    ep_len_mean          | 1.57e+04   |
# |    ep_rew_mean          | 832        |
# | time/                   |            |
# |    fps                  | 30         |
# |    iterations           | 312        |
# |    time_elapsed         | 5206       |
# |    total_timesteps      | 159744     |
# | train/                  |            |
# |    approx_kl            | 0.00261899 |
# |    clip_fraction        | 0.0102     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.963     |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0005     |
# |    loss                 | 0.0399     |
# |    n_updates            | 3110       |
# |    policy_gradient_loss | -0.00143   |
# |    value_loss           | 0.149      |
# ----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.57e+04     |
# |    ep_rew_mean          | 832          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 313          |
# |    time_elapsed         | 5230         |
# |    total_timesteps      | 160256       |
# | train/                  |              |
# |    approx_kl            | 0.0066360384 |
# |    clip_fraction        | 0.0471       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.02        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0106       |
# |    n_updates            | 3120         |
# |    policy_gradient_loss | -0.00358     |
# |    value_loss           | 0.118        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.57e+04    |
# |    ep_rew_mean          | 832         |
# | time/                   |             |
# |    fps                  | 30          |
# |    iterations           | 314         |
# |    time_elapsed         | 5252        |
# |    total_timesteps      | 160768      |
# | train/                  |             |
# |    approx_kl            | 0.008149518 |
# |    clip_fraction        | 0.065       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0005      |
# |    loss                 | 0.0353      |
# |    n_updates            | 3130        |
# |    policy_gradient_loss | -0.00387    |
# |    value_loss           | 0.108       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.57e+04     |
# |    ep_rew_mean          | 832          |
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 315          |
# |    time_elapsed         | 5273         |
# |    total_timesteps      | 161280       |
# | train/                  |              |
# |    approx_kl            | 0.0008484747 |
# |    clip_fraction        | 0.0113       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.06        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0005       |
# |    loss                 | 0.0363       |
# |    n_updates            | 3140         |
# |    policy_gradient_loss | -0.000551    |
# |    value_loss           | 0.0989       |
# ------------------------------------------
