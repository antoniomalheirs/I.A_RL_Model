# %%
import os 
import gym
import gym_super_mario_bros
from gym_super_mario_bros.actions import RIGHT_ONLY
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback
from nes_py.wrappers import JoypadSpace
import tensorboard as tf

# Função para criar o ambiente
def make_env():
    env = gym_super_mario_bros.make('SuperMarioBros-v1')
    env = JoypadSpace(env, RIGHT_ONLY)
    env = gym.wrappers.GrayScaleObservation(env, keep_dim=True)
    env = CustomRescaleObservation(env, low=0, high=255)
    env = gym.wrappers.FrameStack(env, num_stack=6)
    return env

# Classe personalizada para redimensionar as observações
class CustomRescaleObservation(gym.ObservationWrapper):
    def __init__(self, env, low, high):
        super(CustomRescaleObservation, self).__init__(env)
        self.low = low
        self.high = high

    def observation(self, observation):
        return observation * (self.high - self.low) + self.low

# Callback personalizado para recompensas e penalidades
class CustomCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(CustomCallback, self).__init__(verbose)
        self.x_pos = None
        self.check_freq = check_freq
        self.save_path = save_path
        self.rewards = 0
        self.time_before = None
        self.progress_bar = None

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        # Obtem informações sobre o ambiente após a etapa
        info = self.locals.get("info", {})

        # Recompensa o agente com base na diferença de x (v) entre os estados
        x_pos_after = info.get("x_pos", 0)
        self.x_pos = x_pos_after
        if self.x_pos is not None:
            v = x_pos_after - self.x_pos
            if v < 0:
                v = 1
            if v > 0:
                v = 2
            if v == 0:
                v = 0

        # Recompensa o agente com base na diferença no relógio (c) entre os estados
        time_after = info.get("time", 0)
        self.time_before = time_after
        if self.time_before is not None:
            c = self.time_before - time_after
            if c >= 0:
                c = 0
            else:
                c = -1

        # Recompensas adicionais por coletar moedas e derrotar inimigos
        coins_collected = info.get("coins", 0)
        enemies_defeated = info.get("enemies_defeated", 0)
        additional_reward = coins_collected * 1 + enemies_defeated * 1

        # Recompensas adicionais com base na eficiência do agente (mais rápido e menos etapas)
        remaining_time = info.get("remaining_time", 0)
        num_steps = info.get("num_steps", 0)
        time_reward = remaining_time * 1
        steps_reward = -num_steps * 1

        # Penaliza o agente por morrer (d)
        d = -15 if "life" in info and info["life"] < 1 else 0

        if info.get("flag_get", False):
            reward = 15
            self.rewards += reward
            self.logger.record("reward", reward)
            return True

        # Soma as recompensas e penalidades para calcular a recompensa total
        reward = v + c + d + additional_reward + time_reward + steps_reward

        # Salva a recompensa total no log
        self.rewards += reward
        self.logger.record("reward", reward)

        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'melhor_modelo_mario_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True


# Cria o ambiente do jogo
env = make_env()

# Diretórios onde seram salvos os modelos e logs
CHECKPOINT_DIR = './mario_model_v3/'
LOG_DIR = './logs_v2/'

# Crie o modelo PPO com a política MlpPolicy ou Use um já salvo
model = PPO("MlpPolicy", env, verbose=1, tensorboard_log=LOG_DIR, batch_size=128, learning_rate=0.0004, vf_coef=0.5, ent_coef=0.01, n_steps=1024)
## model = PPO.load('./mario_model_v3/melhor_modelo_mario_450000', env=env, tensorboard_log=LOG_DIR, batch_size=128, learning_rate=0.0005, vf_coef=0.5, ent_coef=0.01) ##2

# Declaração do treinamento com callback personalizado
custom_callback = CustomCallback(check_freq=50000, save_path=CHECKPOINT_DIR)
model.learn(total_timesteps=1000000, callback=custom_callback)

# Salva o modelo depois de concluir
model.save("mario_model")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ./logs_v2/PPO_6
# -----------------------------
# | reward             | 0    |
# | time/              |      |
# |    fps             | 132  |
# |    iterations      | 1    |
# |    time_elapsed    | 7    |
# |    total_timesteps | 1024 |
# -----------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 53          |
# |    iterations           | 2           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.008185441 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.00644    |
# |    learning_rate        | 0.0004      |
# |    loss                 | 90.3        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00243    |
# |    value_loss           | 199         |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 45          |
# |    iterations           | 3           |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.012162483 |
# |    clip_fraction        | 0.0177      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0382      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.000491   |
# |    value_loss           | 1.67        |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 4           |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011604371 |
# |    clip_fraction        | 0.0492      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0134      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 0.632       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 5           |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.005898495 |
# |    clip_fraction        | 0.00381     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.054       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.000282    |
# |    value_loss           | 0.347       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 6           |
# |    time_elapsed         | 162         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013165159 |
# |    clip_fraction        | 0.0362      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.57       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0232      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00293    |
# |    value_loss           | 0.252       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 7            |
# |    time_elapsed         | 195          |
# |    total_timesteps      | 7168         |
# | train/                  |              |
# |    approx_kl            | 0.0128281405 |
# |    clip_fraction        | 0.0296       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.55        |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0245       |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00362     |
# |    value_loss           | 0.214        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 8           |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009876861 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0221      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00604    |
# |    value_loss           | 0.164       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 9           |
# |    time_elapsed         | 258         |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.015943173 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0004      |
# |    loss                 | 62.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00516    |
# |    value_loss           | 111         |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 10          |
# |    time_elapsed         | 289         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008837102 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | -5.36e-05   |
# |    learning_rate        | 0.0004      |
# |    loss                 | 52.1        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 96.7        |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 11          |
# |    time_elapsed         | 320         |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.010398678 |
# |    clip_fraction        | 0.00791     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0897      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.000515   |
# |    value_loss           | 0.991       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 12          |
# |    time_elapsed         | 350         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.010750879 |
# |    clip_fraction        | 0.0592      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0757      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00471    |
# |    value_loss           | 0.658       |
# -----------------------------------------
# ----------------------------------------
# | reward                  | 0          |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 13         |
# |    time_elapsed         | 378        |
# |    total_timesteps      | 13312      |
# | train/                  |            |
# |    approx_kl            | 0.01754687 |
# |    clip_fraction        | 0.0828     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0004     |
# |    loss                 | 0.122      |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00521   |
# |    value_loss           | 0.433      |
# ----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | time/                   |              |
# |    fps                  | 34           |
# |    iterations           | 14           |
# |    time_elapsed         | 409          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0072655464 |
# |    clip_fraction        | 0.0377       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0889       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00306     |
# |    value_loss           | 0.353        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 15          |
# |    time_elapsed         | 441         |
# |    total_timesteps      | 15360       |
# | train/                  |             |
# |    approx_kl            | 0.008395891 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0144      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00209    |
# |    value_loss           | 0.195       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 16          |
# |    time_elapsed         | 473         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011659792 |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0243      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00497    |
# |    value_loss           | 0.149       |
# -----------------------------------------
# -------------------------------------------
# | reward                  | 0             |
# | time/                   |               |
# |    fps                  | 34            |
# |    iterations           | 17            |
# |    time_elapsed         | 504           |
# |    total_timesteps      | 17408         |
# | train/                  |               |
# |    approx_kl            | 0.00013780833 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.53         |
# |    explained_variance   | -1.19e-07     |
# |    learning_rate        | 0.0004        |
# |    loss                 | 134           |
# |    n_updates            | 160           |
# |    policy_gradient_loss | 0.0002        |
# |    value_loss           | 231           |
# -------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 18          |
# |    time_elapsed         | 536         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007592939 |
# |    clip_fraction        | 0.0461      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0004      |
# |    loss                 | 17.7        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0025     |
# |    value_loss           | 64.8        |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 19          |
# |    time_elapsed         | 566         |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.008025258 |
# |    clip_fraction        | 0.014       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0252      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00119    |
# |    value_loss           | 0.655       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 20          |
# |    time_elapsed         | 595         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011642994 |
# |    clip_fraction        | 0.0466      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0295      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00419    |
# |    value_loss           | 0.449       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 21          |
# |    time_elapsed         | 624         |
# |    total_timesteps      | 21504       |
# | train/                  |             |
# |    approx_kl            | 0.010833239 |
# |    clip_fraction        | 0.0595      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0339      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00511    |
# |    value_loss           | 0.337       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | time/                   |              |
# |    fps                  | 34           |
# |    iterations           | 22           |
# |    time_elapsed         | 654          |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0041618207 |
# |    clip_fraction        | 0.00645      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0352       |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.000738    |
# |    value_loss           | 0.238        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 23          |
# |    time_elapsed         | 683         |
# |    total_timesteps      | 23552       |
# | train/                  |             |
# |    approx_kl            | 0.011370236 |
# |    clip_fraction        | 0.0754      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.025       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00765    |
# |    value_loss           | 0.176       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+04    |
# |    ep_rew_mean          | 402         |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 24          |
# |    time_elapsed         | 712         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.017034683 |
# |    clip_fraction        | 0.0903      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0222      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00834    |
# |    value_loss           | 0.139       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 2.41e+04     |
# |    ep_rew_mean          | 402          |
# | time/                   |              |
# |    fps                  | 34           |
# |    iterations           | 25           |
# |    time_elapsed         | 742          |
# |    total_timesteps      | 25600        |
# | train/                  |              |
# |    approx_kl            | 0.0012452346 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.48        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 222          |
# |    n_updates            | 240          |
# |    policy_gradient_loss | 0.000128     |
# |    value_loss           | 416          |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+04    |
# |    ep_rew_mean          | 402         |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 26          |
# |    time_elapsed         | 771         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015044361 |
# |    clip_fraction        | 0.0652      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.00477     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00748    |
# |    value_loss           | 0.46        |
# -----------------------------------------
# ----------------------------------------
# | reward                  | 0          |
# | rollout/                |            |
# |    ep_len_mean          | 2.41e+04   |
# |    ep_rew_mean          | 402        |
# | time/                   |            |
# |    fps                  | 34         |
# |    iterations           | 27         |
# |    time_elapsed         | 800        |
# |    total_timesteps      | 27648      |
# | train/                  |            |
# |    approx_kl            | 0.01007922 |
# |    clip_fraction        | 0.0388     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.49      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0004     |
# |    loss                 | 0.0178     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.00252   |
# |    value_loss           | 0.221      |
# ----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 2.41e+04    |
# |    ep_rew_mean          | 402         |
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 28          |
# |    time_elapsed         | 824         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010941636 |
# |    clip_fraction        | 0.0771      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.00919     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00555    |
# |    value_loss           | 0.177       |
# -----------------------------------------
# ----------------------------------------
# | reward                  | 0          |
# | rollout/                |            |
# |    ep_len_mean          | 2.41e+04   |
# |    ep_rew_mean          | 402        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 29         |
# |    time_elapsed         | 846        |
# |    total_timesteps      | 29696      |
# | train/                  |            |
# |    approx_kl            | 0.01248556 |
# |    clip_fraction        | 0.0265     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.5       |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0004     |
# |    loss                 | 0.0394     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.00206   |
# |    value_loss           | 0.145      |
# ----------------------------------------
# ----------------------------------------
# | reward                  | 0          |
# | rollout/                |            |
# |    ep_len_mean          | 2.41e+04   |
# |    ep_rew_mean          | 402        |
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 30         |
# |    time_elapsed         | 868        |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.00807111 |
# |    clip_fraction        | 0.0156     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.46      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0004     |
# |    loss                 | 0.0268     |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.00132   |
# |    value_loss           | 0.124      |
# ----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 2.41e+04     |
# |    ep_rew_mean          | 402          |
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 31           |
# |    time_elapsed         | 891          |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0073505943 |
# |    clip_fraction        | 0.0492       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 1.79e-07     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0134       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00391     |
# |    value_loss           | 0.107        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 35          |
# |    iterations           | 32          |
# |    time_elapsed         | 914         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013655392 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0191      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00966    |
# |    value_loss           | 0.0989      |
# -----------------------------------------
# -------------------------------------------
# | reward                  | 0             |
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 496           |
# | time/                   |               |
# |    fps                  | 36            |
# |    iterations           | 33            |
# |    time_elapsed         | 936           |
# |    total_timesteps      | 33792         |
# | train/                  |               |
# |    approx_kl            | 0.00023812946 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.41         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0004        |
# |    loss                 | 152           |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000756     |
# |    value_loss           | 288           |
# -------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 496          |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 34           |
# |    time_elapsed         | 959          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0058642416 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.43        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 19.3         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00199     |
# |    value_loss           | 37.9         |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 35          |
# |    time_elapsed         | 981         |
# |    total_timesteps      | 35840       |
# | train/                  |             |
# |    approx_kl            | 0.009029151 |
# |    clip_fraction        | 0.0699      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.504       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00338    |
# |    value_loss           | 4.87        |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 36          |
# |    time_elapsed         | 1003        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011846535 |
# |    clip_fraction        | 0.0668      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.47       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.00881     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00518    |
# |    value_loss           | 0.216       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 37          |
# |    time_elapsed         | 1025        |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.013562356 |
# |    clip_fraction        | 0.0346      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0354      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00265    |
# |    value_loss           | 0.18        |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 496          |
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 38           |
# |    time_elapsed         | 1047         |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0066663306 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0178       |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 0.144        |
# ------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 496          |
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 39           |
# |    time_elapsed         | 1070         |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0117215635 |
# |    clip_fraction        | 0.0239       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0553       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00144     |
# |    value_loss           | 0.123        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 40          |
# |    time_elapsed         | 1092        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.015650183 |
# |    clip_fraction        | 0.0818      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0121      |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00646    |
# |    value_loss           | 0.108       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 496          |
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 41           |
# |    time_elapsed         | 1115         |
# |    total_timesteps      | 41984        |
# | train/                  |              |
# |    approx_kl            | 0.0001622152 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.54        |
# |    explained_variance   | 5.96e-08     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 107          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | 0.000511     |
# |    value_loss           | 268          |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 42          |
# |    time_elapsed         | 1138        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.013685783 |
# |    clip_fraction        | 0.0229      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 62.3        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00442    |
# |    value_loss           | 72.1        |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 43          |
# |    time_elapsed         | 1160        |
# |    total_timesteps      | 44032       |
# | train/                  |             |
# |    approx_kl            | 0.006256141 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.113       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00232    |
# |    value_loss           | 0.428       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 496          |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 44           |
# |    time_elapsed         | 1183         |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0029703076 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.55        |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0857       |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000121    |
# |    value_loss           | 0.371        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 45          |
# |    time_elapsed         | 1205        |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.011745983 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0803      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00618    |
# |    value_loss           | 0.311       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 46          |
# |    time_elapsed         | 1228        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011739565 |
# |    clip_fraction        | 0.0648      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.51       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0951      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 0.24        |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 496         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 47          |
# |    time_elapsed         | 1251        |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.011978341 |
# |    clip_fraction        | 0.0769      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0148      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00506    |
# |    value_loss           | 0.125       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 487          |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 48           |
# |    time_elapsed         | 1274         |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0113093015 |
# |    clip_fraction        | 0.049        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.47        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0315       |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00406     |
# |    value_loss           | 0.11         |
# ------------------------------------------
# -------------------------------------------
# | reward                  | 0             |
# | rollout/                |               |
# |    ep_len_mean          | 1.62e+04      |
# |    ep_rew_mean          | 487           |
# | time/                   |               |
# |    fps                  | 38            |
# |    iterations           | 49            |
# |    time_elapsed         | 1300          |
# |    total_timesteps      | 50176         |
# | train/                  |               |
# |    approx_kl            | 0.00013642246 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.42         |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0004        |
# |    loss                 | 124           |
# |    n_updates            | 480           |
# |    policy_gradient_loss | 0.00059       |
# |    value_loss           | 310           |
# -------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 487         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 50          |
# |    time_elapsed         | 1323        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014090359 |
# |    clip_fraction        | 0.0256      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0004      |
# |    loss                 | -0.0103     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0027     |
# |    value_loss           | 0.267       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 487         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 51          |
# |    time_elapsed         | 1346        |
# |    total_timesteps      | 52224       |
# | train/                  |             |
# |    approx_kl            | 0.009026313 |
# |    clip_fraction        | 0.0572      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0315      |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00467    |
# |    value_loss           | 0.147       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 487          |
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 52           |
# |    time_elapsed         | 1370         |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0056239264 |
# |    clip_fraction        | 0.0565       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.35        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0321       |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.00431     |
# |    value_loss           | 0.127        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 487         |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 53          |
# |    time_elapsed         | 1393        |
# |    total_timesteps      | 54272       |
# | train/                  |             |
# |    approx_kl            | 0.006110141 |
# |    clip_fraction        | 0.0434      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0272      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0026     |
# |    value_loss           | 0.113       |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# |    ep_rew_mean          | 487          |
# | time/                   |              |
# |    fps                  | 39           |
# |    iterations           | 54           |
# |    time_elapsed         | 1416         |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0066042813 |
# |    clip_fraction        | 0.0552       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0315       |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00396     |
# |    value_loss           | 0.103        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 1.62e+04    |
# |    ep_rew_mean          | 487         |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 55          |
# |    time_elapsed         | 1439        |
# |    total_timesteps      | 56320       |
# | train/                  |             |
# |    approx_kl            | 0.004346645 |
# |    clip_fraction        | 0.00381     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0295      |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.000142   |
# |    value_loss           | 0.0976      |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 1.62e+04     |
# ...
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 6.1e+03      |
# |    ep_rew_mean          | 1.66e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 961          |
# |    time_elapsed         | 26641        |
# |    total_timesteps      | 984064       |
# | train/                  |              |
# |    approx_kl            | 0.0045356844 |
# |    clip_fraction        | 0.0518       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.83        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0354       |
# |    n_updates            | 9600         |
# |    policy_gradient_loss | -0.00421     |
# |    value_loss           | 0.141        |
# ------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 6.1e+03      |
# |    ep_rew_mean          | 1.66e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 962          |
# |    time_elapsed         | 26668        |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0044006268 |
# |    clip_fraction        | 0.0415       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.791       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0171       |
# |    n_updates            | 9610         |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 0.115        |
# ------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 6.1e+03      |
# |    ep_rew_mean          | 1.66e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 963          |
# |    time_elapsed         | 26697        |
# |    total_timesteps      | 986112       |
# | train/                  |              |
# |    approx_kl            | 0.0051780874 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.752       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0441       |
# |    n_updates            | 9620         |
# |    policy_gradient_loss | -0.00162     |
# |    value_loss           | 0.105        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 6.1e+03     |
# |    ep_rew_mean          | 1.66e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 964         |
# |    time_elapsed         | 26725       |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.003548083 |
# |    clip_fraction        | 0.047       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.753      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0274      |
# |    n_updates            | 9630        |
# |    policy_gradient_loss | -0.00373    |
# |    value_loss           | 0.0992      |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 6.1e+03      |
# |    ep_rew_mean          | 1.66e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 965          |
# |    time_elapsed         | 26754        |
# |    total_timesteps      | 988160       |
# | train/                  |              |
# |    approx_kl            | 0.0038007875 |
# |    clip_fraction        | 0.0269       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0244       |
# |    n_updates            | 9640         |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 0.0957       |
# ------------------------------------------
# -------------------------------------------
# | reward                  | 0             |
# | rollout/                |               |
# |    ep_len_mean          | 6.1e+03       |
# |    ep_rew_mean          | 1.66e+03      |
# | time/                   |               |
# |    fps                  | 36            |
# |    iterations           | 966           |
# |    time_elapsed         | 26782         |
# |    total_timesteps      | 989184        |
# | train/                  |               |
# |    approx_kl            | 0.00026559923 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.764        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0004        |
# |    loss                 | 167           |
# |    n_updates            | 9650          |
# |    policy_gradient_loss | 0.00146       |
# |    value_loss           | 357           |
# -------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 6.1e+03      |
# |    ep_rew_mean          | 1.66e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 967          |
# |    time_elapsed         | 26809        |
# |    total_timesteps      | 990208       |
# | train/                  |              |
# |    approx_kl            | 0.0035779607 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.775       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.129        |
# |    n_updates            | 9660         |
# |    policy_gradient_loss | -0.00173     |
# |    value_loss           | 0.378        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 6.1e+03     |
# |    ep_rew_mean          | 1.66e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 968         |
# |    time_elapsed         | 26837       |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.005969923 |
# |    clip_fraction        | 0.0455      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.853      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.134       |
# |    n_updates            | 9670        |
# |    policy_gradient_loss | -0.0021     |
# |    value_loss           | 0.29        |
# -----------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 6.1e+03      |
# |    ep_rew_mean          | 1.66e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 969          |
# |    time_elapsed         | 26866        |
# |    total_timesteps      | 992256       |
# | train/                  |              |
# |    approx_kl            | 0.0052396753 |
# |    clip_fraction        | 0.0368       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.87        |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.106        |
# |    n_updates            | 9680         |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 0.263        |
# ------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 6.1e+03      |
# |    ep_rew_mean          | 1.66e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 970          |
# |    time_elapsed         | 26894        |
# |    total_timesteps      | 993280       |
# | train/                  |              |
# |    approx_kl            | 0.0069044237 |
# |    clip_fraction        | 0.0304       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.812       |
# |    explained_variance   | 1.19e-07     |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.125        |
# |    n_updates            | 9690         |
# |    policy_gradient_loss | -0.00363     |
# |    value_loss           | 0.256        |
# ------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 6.1e+03      |
# |    ep_rew_mean          | 1.66e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 971          |
# |    time_elapsed         | 26923        |
# |    total_timesteps      | 994304       |
# | train/                  |              |
# |    approx_kl            | 0.0014759954 |
# |    clip_fraction        | 0.00439      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.794       |
# |    explained_variance   | -1.19e-07    |
# |    learning_rate        | 0.0004       |
# |    loss                 | 0.0912       |
# |    n_updates            | 9700         |
# |    policy_gradient_loss | -4.56e-05    |
# |    value_loss           | 0.215        |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 6.1e+03     |
# |    ep_rew_mean          | 1.66e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 972         |
# |    time_elapsed         | 26951       |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.004132745 |
# |    clip_fraction        | 0.0621      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.832      |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0276      |
# |    n_updates            | 9710        |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 0.0971      |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 6.1e+03     |
# |    ep_rew_mean          | 1.66e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 973         |
# |    time_elapsed         | 26980       |
# |    total_timesteps      | 996352      |
# | train/                  |             |
# |    approx_kl            | 0.006561472 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.771      |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0334      |
# |    n_updates            | 9720        |
# |    policy_gradient_loss | -0.00311    |
# |    value_loss           | 0.0913      |
# -----------------------------------------
# -------------------------------------------
# | reward                  | 0             |
# | rollout/                |               |
# |    ep_len_mean          | 6.1e+03       |
# |    ep_rew_mean          | 1.66e+03      |
# | time/                   |               |
# |    fps                  | 36            |
# |    iterations           | 974           |
# |    time_elapsed         | 27008         |
# |    total_timesteps      | 997376        |
# | train/                  |               |
# |    approx_kl            | 0.00056766573 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.766        |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0004        |
# |    loss                 | 154           |
# |    n_updates            | 9730          |
# |    policy_gradient_loss | 0.000946      |
# |    value_loss           | 263           |
# -------------------------------------------
# ------------------------------------------
# | reward                  | 0            |
# | rollout/                |              |
# |    ep_len_mean          | 6.1e+03      |
# |    ep_rew_mean          | 1.66e+03     |
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 975          |
# |    time_elapsed         | 27036        |
# |    total_timesteps      | 998400       |
# | train/                  |              |
# |    approx_kl            | 0.0015324457 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.772       |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0004       |
# |    loss                 | 49.7         |
# |    n_updates            | 9740         |
# |    policy_gradient_loss | -0.00027     |
# |    value_loss           | 81.8         |
# ------------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 6.1e+03     |
# |    ep_rew_mean          | 1.66e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 976         |
# |    time_elapsed         | 27065       |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.005450301 |
# |    clip_fraction        | 0.0406      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.77       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0387      |
# |    n_updates            | 9750        |
# |    policy_gradient_loss | -0.00469    |
# |    value_loss           | 0.291       |
# -----------------------------------------
# -----------------------------------------
# | reward                  | 0           |
# | rollout/                |             |
# |    ep_len_mean          | 6.1e+03     |
# |    ep_rew_mean          | 1.66e+03    |
# | time/                   |             |
# |    fps                  | 36          |
# |    iterations           | 977         |
# |    time_elapsed         | 27096       |
# |    total_timesteps      | 1000448     |
# | train/                  |             |
# |    approx_kl            | 0.003450461 |
# |    clip_fraction        | 0.0313      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.772      |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0004      |
# |    loss                 | 0.0442      |
# |    n_updates            | 9760        |
# |    policy_gradient_loss | -0.00282    |
# |    value_loss           | 0.209       |
# -----------------------------------------
